# %%
def summary_stats(vector:list)->dict:
    n = len(vector)
    mean = sum(vector)/n
    variance = sum( (x - mean)**2 for x in vector )/(n-1)
    std = variance**0.5
    sortvector = sorted(vector)
    if (n%2==0):
        median = (sortvector[n//2-1]+sortvector[n//2])/2
    else:
        median = sortvector[n//2]
    return {"n":n, "mean":round(mean,4), "variance":round(variance,4), "std":round(std,4), "median":median}
summary_stats([12, 15, 14, 10, 18, 21, 13, 16])
# Out:
# {'n': 8, 'mean': 14.875, 'variance': 12.125, 'std': 3.4821, 'median': 14.5}

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
summary_stats(df['sepal_length'])
# Out:
# {'n': 150, 'mean': 5.8433, 'variance': 0.6857, 'std': 0.8281, 'median': 5.8}

# %%
for col in df.select_dtypes(include='number').columns:
    print(col,summary_stats(df[col]))
# Out:
# sepal_length {'n': 150, 'mean': 5.8433, 'variance': 0.6857, 'std': 0.8281, 'median': 5.8}
# sepal_width {'n': 150, 'mean': 3.0573, 'variance': 0.19, 'std': 0.4359, 'median': 3.0}
# petal_length {'n': 150, 'mean': 3.758, 'variance': 3.1163, 'std': 1.7653, 'median': 4.35}
# petal_width {'n': 150, 'mean': 1.1993, 'variance': 0.581, 'std': 0.7622, 'median': 1.3}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['sepal_length'])
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sns.scatterplot(data=df, x='sepal_length', y='petal_length', hue='species')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

print(df.columns[0])
for i in range(5):
    sns.histplot(df[df.columns[i]])
    plt.show()
    sns.scatterplot(data=df,  x='sepal_length', y=df.columns[i], hue = 'species')
    plt.show()
# Out:
# sepal_length

# %%
sns.pairplot(df, hue='species')
plt.show()

# %%
print(df.groupby('species')['petal_length'].mean())
df.groupby('species').mean()
# Out:
# species
# setosa        1.462
# versicolor    4.260
# virginica     5.552
# Name: petal_length, dtype: float64
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
sns.pairplot(df, hue='species');

# %%
df['petal_ratio'] = df['petal_length'] / df['petal_width']
print(df.head())
df['sepal_ratio'] = df['sepal_length'] / df['sepal_width']
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  petal_ratio  \
# 0           5.1          3.5           1.4          0.2  setosa          7.0
# 1           4.9          3.0           1.4          0.2  setosa          7.0
# 2           4.7          3.2           1.3          0.2  setosa          6.5
# 3           4.6          3.1           1.5          0.2  setosa          7.5
# 4           5.0          3.6           1.4          0.2  setosa          7.0
#
#    sepal_ratio
# 0     1.457143
# 1     1.633333
# 2     1.468750
# 3     1.483871
# 4     1.388889
#    sepal_length  sepal_width  petal_length  petal_width species  petal_ratio  \
# 0           5.1          3.5           1.4          0.2  setosa          7.0
# 1           4.9          3.0           1.4          0.2  setosa          7.0
# 2           4.7          3.2           1.3          0.2  setosa          6.5
# 3           4.6          3.1           1.5          0.2  setosa          7.5
# ...

# %%
df == 0.2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species  \
# 0           False        False         False         True    False
# 1           False        False         False         True    False
# 2           False        False         False         True    False
# 3           False        False         False         True    False
# 4           False        False         False         True    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
#      petal_ratio  sepal_ratio
# 0          False        False
# 1          False        False
# 2          False        False
# 3          False        False
# ...

# %%
df[(df['species'] == 'setosa') & (df['sepal_length'] > 5)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species  petal_ratio  \
# 0            5.1          3.5           1.4          0.2  setosa     7.000000
# 5            5.4          3.9           1.7          0.4  setosa     4.250000
# 10           5.4          3.7           1.5          0.2  setosa     7.500000
# 14           5.8          4.0           1.2          0.2  setosa     6.000000
# 15           5.7          4.4           1.5          0.4  setosa     3.750000
# 16           5.4          3.9           1.3          0.4  setosa     3.250000
# 17           5.1          3.5           1.4          0.3  setosa     4.666667
# 18           5.7          3.8           1.7          0.3  setosa     5.666667
# 19           5.1          3.8           1.5          0.3  setosa     5.000000
# 20           5.4          3.4           1.7          0.2  setosa     8.500000
# 21           5.1          3.7           1.5          0.4  setosa     3.750000
# ...

# %%
df[
    (df['sepal_length']==4.7)&(df['sepal_length']==4.7)
    ]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species  petal_ratio  \
# 2            4.7          3.2           1.3          0.2  setosa          6.5
# 29           4.7          3.2           1.6          0.2  setosa          8.0
#
#     sepal_ratio
# 2       1.46875
# 29      1.46875

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# petal_ratio     0
# sepal_ratio     0
# dtype: int64

# %%
import numpy as np

df_dirty = df.copy()
df_dirty.loc[3:7, 'sepal_length'] = np.nan
df_dirty.isnull().sum()
# Out:
# sepal_length    5
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# petal_ratio     0
# sepal_ratio     0
# dtype: int64

# %%
df_dirty.fillna(df_dirty.mean(numeric_only=True))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0        5.100000          3.5           1.4          0.2     setosa
# 1        4.900000          3.0           1.4          0.2     setosa
# 2        4.700000          3.2           1.3          0.2     setosa
# 3        5.875172          3.1           1.5          0.2     setosa
# 4        5.875172          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145      6.700000          3.0           5.2          2.3  virginica
# 146      6.300000          2.5           5.0          1.9  virginica
# 147      6.500000          3.0           5.2          2.0  virginica
# 148      6.200000          3.4           5.4          2.3  virginica
# 149      5.900000          3.0           5.1          1.8  virginica
#
#      petal_ratio  sepal_ratio
# 0       7.000000     1.457143
# 1       7.000000     1.633333
# 2       6.500000     1.468750
# ...

# %%
df_dirty['sepal_length'].fillna(df_dirty['sepal_length'].mean())
# Out:
# 0      5.100000
# 1      4.900000
# 2      4.700000
# 3      5.875172
# 4      5.875172
#          ...
# 145    6.700000
# 146    6.300000
# 147    6.500000
# 148    6.200000
# 149    5.900000
# Name: sepal_length, Length: 150, dtype: float64

# %%
df_dirty.dropna()
df_dirty.dropna().reset_index(drop=True)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.4          2.9           1.4          0.2     setosa
# 4             4.9          3.1           1.5          0.1     setosa
# ..            ...          ...           ...          ...        ...
# 140           6.7          3.0           5.2          2.3  virginica
# 141           6.3          2.5           5.0          1.9  virginica
# 142           6.5          3.0           5.2          2.0  virginica
# 143           6.2          3.4           5.4          2.3  virginica
# 144           5.9          3.0           5.1          1.8  virginica
#
#      petal_ratio  sepal_ratio
# 0       7.000000     1.457143
# 1       7.000000     1.633333
# 2       6.500000     1.468750
# ...

# %%
df1 = pd.DataFrame({
    'species': ['setosa', 'versicolor', 'virginica'],
    'origin': ['Asia', 'America', 'Europe']
})

# %%
df2 = pd.DataFrame({
    'species': ['setosa', 'versicolor', 'virginica'],
    'discovery_year': [1936, 1928, 1936]
})

# %%
pd.merge(df1, df2, on='species')
# Out:
#       species   origin  discovery_year
# 0      setosa     Asia            1936
# 1  versicolor  America            1928
# 2   virginica   Europe            1936

# %%
df3 = pd.DataFrame({
    'species': ['setosa', 'versicolor'],
    'price': [2.5, 3.1]
})

pd.merge(df1, df3, on='species')
# Out:
#       species   origin  price
# 0      setosa     Asia    2.5
# 1  versicolor  America    3.1

# %%
pd.merge(df1, df3, on='species', how='left')
# Out:
#       species   origin  price
# 0      setosa     Asia    2.5
# 1  versicolor  America    3.1
# 2   virginica   Europe    NaN
